# %%
#wap to find largest and second largest in the list
lst=eval(input("Enter the list: "))
for i in range(len(lst)):
# Out:
#   Cell In[14], line 4
#
#     ^
# SyntaxError: incomplete input

# %%
#list 
lst=[7,-4,-2,5,6,19,11]
print(list[1::4])
# Out:
# list[slice(1, None, 4)]

# %%
#add in list 
lst=[7,-4,-2,5,6,19,11]
lst.append("Hi")
lst.insert(2,69)
lst2=[1,2,3]
lst.extend(lst2) 
#to extend -> lst+=lst2
print(lst)
# Out:
# [7, -4, 69, -2, 5, 6, 19, 11, 'Hi', 1, 2, 3]

# %%
#dlt element 
lst=[7,-4,-2,5,6,19,11]
lst.pop(2)
lst.pop(3)
print(lst)
# Out:
# [7, -4, 5, 19, 11]

# %%
#prefix sum
lst=[2,3,1,4,5,6,2,8]

lst_sum=0
for i in lst:
    lst_sum += i
ans=[]
for i in lst:
    ans.append(lst_sum - i)
    
print(ans)
print(lst)




# def prefix_sum(lst):
#     res = []
#     total = 0
#     for x in lst:
#         res.append(total)
#         total += x
        
#     return res
# print(prefix_sum(lst))
# Out:
# [29, 28, 30, 27, 26, 25, 29, 23]
# [2, 3, 1, 4, 5, 6, 2, 8]

# %%
#sum of list -> append in new lst 
lst=[[1,3,5,6],[3,4,5],[3,5,7],[10,20,30]]
lst_sum=0
for i in lst:
    lst_sum += i
