# %%
#wap to take list as input , increase even no. by 5 & decrease odd by 5
lst=eval(input("Enter the list: "))
for i in range(len(lst)):
    if i%2==0:
        print(i+5,end=" ")
    else:
        print(i-5,end="")
# Out:
# 5 -47 -2

# %%
#wap to find largest and second largest in the list
lst=eval(input("Enter the list: "))
for i in range(len(lst)):
